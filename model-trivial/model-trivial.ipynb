# %%
# Standard scientific libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Settings matplotlib
# %matplotlib inline
# Settings pandas
# Modelica librairies
import DyMat as dm

# %%
R = dm.DyMatFile("./Hello_res.mat")
R.names()
t,tname,tdesc = R.abscissa('x')
x = R.data('x')
plt.plot(t,x)
plt.show()

# %%
# Print available variables
R.names()
# Out:
# dict_keys(['x', 'der(x)'])

# %%
# Extract a variable
x = R.data('x')
dx = R.data('der(x)')

# %%
# Extract abscisse of the variable
t,tname,tdesc = R.abscissa('x')

# %%
plt.plot(t,x,t,dx)
# Out:
# [<matplotlib.lines.Line2D at 0x7f0b3893c3c8>,
#  <matplotlib.lines.Line2D at 0x7f0b3893cd30>]
